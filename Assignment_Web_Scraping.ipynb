# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
pip install beautifulsoup4

# %%
import requests

url = "https://www.instagram.com/api/v1/tags/logged_out_web_info/?tag_name=pemilu"

payload = {}
headers = {
  'authority': 'www.instagram.com',
  'accept': '*/*',
  'accept-language': 'en-US,en;q=0.9',
  'cookie': 'ig_did=1545BC2A-478B-4BBA-8EBD-64B22F9A3028; ig_nrcb=1; ps_l=0; ps_n=0; datr=IAW_ZWmSfw-4IU9B8pCxdWAW; fbm_124024574287414=base_domain=.instagram.com; mid=Zb8FIgALAAHXPbz9fx5HEbDopgN8; shbid="1114\\0541553838576\\0541738553690:01f7d6a46fda1e6535772521911fce6a32104acfa73fa05de86b3436001468ea9b41c4d2"; shbts="1707017690\\0541553838576\\0541738553690:01f783a067840c7ff1e2fe3d1c780fdd864e9760dab5eb9a601c290e58122726dd9b3bde"; csrftoken=zYWQLYkSjovK9EyXcg3IsT56Oda7o8nv; fbsr_124024574287414=W-_06IvqskPqOIchq8Zt7Dd7GCLBzX2YukvuUYZLIEw....; fbsr_124024574287414=7ctd1OI2zmZwaJALsw6Aje4WST20HQ4jIi7vkt0s8bg....; csrftoken=6XwkG9ZCGmHneVUnnfWXeOD2M9Z8fOLK; ds_user_id=1553838576',
  'dpr': '1',
  'referer': 'https://www.instagram.com/explore/tags/pemilu/',
  'sec-ch-prefers-color-scheme': 'dark',
  'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
  'sec-ch-ua-full-version-list': '"Not A(Brand";v="99.0.0.0", "Google Chrome";v="121.0.6167.140", "Chromium";v="121.0.6167.140"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-model': '""',
  'sec-ch-ua-platform': '"Windows"',
  'sec-ch-ua-platform-version': '"15.0.0"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
  'viewport-width': '478',
  'x-asbd-id': '129477',
  'x-csrftoken': 'zYWQLYkSjovK9EyXcg3IsT56Oda7o8nv',
  'x-ig-app-id': '936619743392459',
  'x-ig-www-claim': '0',
  'x-requested-with': 'XMLHttpRequest'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"count":562116,"data":{"hashtag":{"id":"17843712556000087","name":"pemilu","allow_following":false,"is_following":false,"is_top_media_only":false,"profile_pic_url":"https://scontent-iad3-2.cdninstagram.com/v/t51.2885-15/424470048_971590161067140_6536761247080472649_n.jpg?stp=c0.180.1440.1440a_dst-jpg_e35_s150x150\u0026_nc_ht=scontent-iad3-2.cdninstagram.com\u0026_nc_cat=100\u0026_nc_ohc=MADws6-PMIkAX_KQdcl\u0026edm=AOUPxh0BAAAA\u0026ccb=7-5\u0026oh=00_AfA048TpchoNk0-tI1kMADWPDhLCHSdx8cZ2iF431muPgw\u0026oe=65C74014\u0026_nc_sid=9dc660","edge_hashtag_to_media":{"count":562116,"page_info":{"has_next_page":true,"end_cursor":"QVFCZXdVdEZzM3ZUYVBBd1o5NER0clJ3QWRROG1VV2dzWDFkUlZxcnd2M2RkTjN4dXlpel9tMFpOYndHR3B1U1JKb1pZWGVjeDZSNVJFNU9aNTZiVUJvNA=="},"edges":[{"node":{"comments_disabled":false,"__typename":"GraphVideo","id":"3296518677647651160","edge_media_to_caption":{"edges":[{"node":{"text":"Kudah Putih telah Melangkah,Kita tunggu Raja untuk mengakhiri permainan Catur ini.😎\n\n#Kudaputih
# ...

# %%
response.json()['data']

# %%
pd.DataFrame(response.json())
# Out:
#           count                                               data status
# hashtag  562116  {'id': '17843712556000087', 'name': 'pemilu', ...     ok

# %%
url = 'https://quotes.toscrape.com/'
page = requests.get(url)
print(page.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# ...

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
quotes = soup.find_all("div", class_='quote')
len(quotes)
# Out:
# 10

# %%
lists = []
for quote in quotes:
  item = dict()
  item['text'] = quote.find("span").text
  item['author'] = quote.find("small").text
  lists.append(item)

# %%
df = pd.DataFrame(lists)
df
# Out:
#                                                 text             author
# 0  “The world as we have created it is a process ...    Albert Einstein
# 1  “It is our choices, Harry, that show what we t...       J.K. Rowling
# 2  “There are only two ways to live your life. On...    Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...        Jane Austen
# 4  “Imperfection is beauty, madness is genius and...     Marilyn Monroe
# 5  “Try not to become a man of success. Rather be...    Albert Einstein
# 6  “It is better to be hated for what you are tha...         André Gide
# 7  “I have not failed. I've just found 10,000 way...   Thomas A. Edison
# 8  “A woman is like a tea bag; you never know how...  Eleanor Roosevelt
# 9  “A day without sunshine is like, you know, nig...       Steve Martin

# %%
df.to_csv('quote.csv', index=False)
